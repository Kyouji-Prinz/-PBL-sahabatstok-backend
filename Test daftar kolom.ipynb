# %%
import pickle

# Sesuaikan jalurnya jika ada yang berbeda
path_model = r"model manual\models\by_mlflow\model_weekly_accessories.pkl"

with open(path_model, 'rb') as file:
    model_ml = pickle.load(file)

# Perintah ajaib untuk mengeluarkan daftar kolom yang diingat model
print("Daftar kolom yang dibutuhkan model:")
print(model_ml.feature_names_in_)
# Out:
# Daftar kolom yang dibutuhkan model:
# ['Discount' 'Quantity_Lag_1' 'Quantity_Lag_2' 'Quantity_Rolling_Mean_3'
#  'Sales_Lag_1' 'Profit_Lag_1' 'Month' 'Year' 'Week_of_Year']
